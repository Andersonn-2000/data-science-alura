# %%
import pandas as pd
import geopandas as gpd 
import matplotlib.pyplot as plt
import os
import fiona

# %%
shapefile_path = '../data/SIRGAS_SHP_estacaometro_point.shp'
#subway_station = gpd.read_file(shapefile_path)
print(os.path.exists(shapefile_path))
# Out:
# True

# %%
try:
    with fiona.open(shapefile_path) as shp:
        print(f'Arquivo válido: {shp}')
except Exception as e:
    print(f'Erro ao abrir o arquivo: {e}')
# Out:
# Erro ao abrir o arquivo: Failed to open dataset (flags=68): ../data/SIRGAS_SHP_estacaometro_point.shp
